# %% [markdown]
# ### Class Predictions
#
# Import the libraries.
# Create a variable which holds the reference to the path that contains your python file and the ResNet model file.
#
# First we created an instance of the ImagePrediction() class, then we set the model type of the prediction object to ResNet by caling the .setModelTypeAsResNet() and then we set the model path of the prediction object to the path of the model file (resnet50_weights_tf_dim_ordering_tf_kernels.h5)

# %%
from imageai.Prediction import ImagePrediction
import os
execution_path = os.getcwd()
prediction = ImagePrediction()
prediction.setModelTypeAsResNet()
prediction.setModelPath("/Users/rounakbose/Git Local/ImageAI/resnet50_weights_tf_dim_ordering_tf_kernels.h5")
prediction.loadModel()

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Next we defined 2 variables to be equal to the function called to predict an image, which is the .predictImage() function, into which we parsed the path to our image and also state the number of prediction results we want to have (values from 1 to 1000) parsing result_count=5.
#
# The .predictImage() function will return 2 array objects with the first (predictions) being an array of predictions and the second (percentage_probabilities) being an array of the corresponding percentage probability for each prediction.
#
# Then we obtain each object in the predictions array, and also obtains the corresponding percentage probability from the percentage_probabilities, and finally prints the result of both to console.
#
# The .predictImage() function takes in the path to an image and can also state the number of predictions we expect the function to return (optional, the default is 5). There are 1000 items in the ImageNet-1000 dataset on which the ResNet model was trained, which means the .predictImage function will return 1000 possible predictions, arranged in order of their probabilities.

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo1.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo1.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# sports_car  :  61.10886335372925
# racer  :  32.71495997905731
# convertible  :  2.122719958424568
# car_wheel  :  1.5144159086048603
# golfcart  :  1.0265165008604527

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo2.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo2.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# sports_car  :  49.3208110332489
# pickup  :  16.77262634038925
# racer  :  12.58697509765625
# car_wheel  :  7.827439904212952
# convertible  :  7.098469138145447

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo3.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo3.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# sports_car  :  86.14164590835571
# car_wheel  :  9.668715298175812
# convertible  :  3.0668575316667557
# racer  :  0.3557374235242605
# Model_T  :  0.3028106642886996

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo4.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo4.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# cab  :  22.172917425632477
# lawn_mower  :  19.249600172042847
# racer  :  18.78214180469513
# motor_scooter  :  8.902619034051895
# sports_car  :  5.368287488818169

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo5.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo5.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# racer  :  44.405150413513184
# go-kart  :  12.346149235963821
# sports_car  :  8.18079262971878
# trailer_truck  :  4.895967245101929
# motor_scooter  :  4.038777947425842

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo6.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo6.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# limousine  :  53.092777729034424
# racer  :  14.56538438796997
# car_wheel  :  13.391682505607605
# sports_car  :  12.919706106185913
# beach_wagon  :  1.3830496929585934

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo7.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo7.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# go-kart  :  99.78013634681702
# racer  :  0.1938468194566667
# sports_car  :  0.02428245061310008
# crash_helmet  :  0.001087721193471225
# lawn_mower  :  0.0001783437141966715

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo8.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo8.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# pickup  :  63.063085079193115
# jeep  :  16.210325062274933
# mobile_home  :  6.259258836507797
# tow_truck  :  6.1729345470666885
# trailer_truck  :  2.8861165046691895

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo9.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo9.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# racer  :  58.356016874313354
# tow_truck  :  17.972663044929504
# sports_car  :  11.26798391342163
# car_wheel  :  2.4026457220315933
# go-kart  :  1.163572259247303

# %%
img=mpimg.imread('/Users/rounakbose/Git Local/ImageAI/photo10.jpg')
imgplot = plt.imshow(img)
plt.show()

predictions, percentage_probabilities = prediction.predictImage("/Users/rounakbose/Git Local/ImageAI/photo10.jpg", result_count=5)
for index in range(len(predictions)):
    print(predictions[index] , " : " , percentage_probabilities[index])
# Out:
# swimming_trunks  :  36.90855801105499
# tub  :  24.888816475868225
# convertible  :  15.704742074012756
# bikini  :  5.129871144890785
# maillot  :  4.721358045935631
